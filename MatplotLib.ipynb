# %% [markdown]
# <a href="https://colab.research.google.com/github/Moksh45/Machine-Learning-Code/blob/main/MatplotLib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MatplotLib**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
#simple data
x=np.arange(0,10)
y=np.arange(11,21)

# %%
a=np.arange(40,50)
b=np.arange(50,60)

# %%
#plotting using matplotlib
#plt scatler
plt.scatter(x,y,c='r')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title("Graph in 2D")
plt.savefig('Test.png') #use for saving the file

# %%
y=x*x

# %%
# plt plot
print(plt.plot(x,y,'ro'))
# Out:
# [<matplotlib.lines.Line2D object at 0x7f42bea44820>]

# %%
print(plt.plot(x,y,'r--'))
# Out:
# [<matplotlib.lines.Line2D object at 0x7f42bea23d60>]

# %%
print(plt.plot(x,y,'r+-'))
# Out:
# [<matplotlib.lines.Line2D object at 0x7f42be981a00>]

# %%
print(plt.plot(x,y,'r*-'))
# Out:
# [<matplotlib.lines.Line2D object at 0x7f42be95e5e0>]

# %%
plt.plot(x,y,'r*',linestyle='dashed',linewidth=2,markersize=12)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('2D diagram')
# Out:
# Text(0.5, 1.0, '2D diagram')

# %%
#creating subplots
plt.subplot(2,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'g*-')
plt.subplot(2,2,3)
plt.plot(x,y,'bo')

# %%
x = np.arange(1,11)
y=3*x+5

# %%
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('2D diagram')
plt.plot(x,y,'r--')

# %%
np.pi
# Out:
# 3.141592653589793

# %%
x=np.arange(0 , 4*np.pi , 0.1)
y=np.sin(x)
plt.title("Sine Wave form")
plt.plot(x,y)
plt.show()

# %% [markdown]
# # **Bar Graph**

# %%
#Bar Plot

x=[2,8,10]
y=[11,16,9]

x2=[3,9,11]
y2=[6,15,7]
plt.bar(x,y,align='center')
plt.bar(x2,y2,color='g')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Bar Graph')
# Out:
# Text(0.5, 1.0, 'Bar Graph')

# %% [markdown]
# # **Histograms**

# %%
a1=np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
plt.hist(a1)
plt.title("Histogram")
# Out:
# Text(0.5, 1.0, 'Histogram')
